# %% [markdown]
# Date of sale Såld 28 oktober 2023,
# Address (or sometimes the name of the plot of land) Strömgatan 4,
# Location of the estate Ytterby, Kungalvs kommun,
# Area in the form of boarea+biarea 105+10 m2 ,
# The number of rooms 5 rum,
# Area of the plot 972 m2 tomt
# Closing price 5 750 000 kr.
#
# Todo: regex på adress som måste va på samma rad,

# %%
# Helper function to flatten a 2D list into a 1D list
def flatten(matrix: list[list[type]]) -> list[type]:
    return [item for sublist in matrix for item in sublist]

# %%
from bs4 import BeautifulSoup
import pandas as pd, matplotlib as pl, glob, os, re

# get all html files in the directory
dir_path = os.getcwd() + "/kungalv_slutpriser/*.html"
files = glob.glob(dir_path)
soups = [BeautifulSoup(open(file, encoding="utf-8"), "html.parser") for file in files]

# regex patterns
date_of_sale_pattern = r"Såld (\d{1,2}) (januari|februari|mars|april|maj|juni|juli|augusti|september|oktober|november|december) (\d{4})"
adress_pattern = r"\b\w+(?:\s+\w+)*\s+\d{1,3}\b"
location_pattern = r"\b\w+(?:,\s+\w+\s+\w+)\b"
bo_and_bi_area_pattern = r"\bboarea\+\bbiarea\s+(\d+\+\d+)\s+m2\b"
nr_of_rooms_pattern = r"\b\d+\s*rum\b"
area_of_plot_pattern = r"\b\d+\s*m2\s+tomt\b"
closing_price_pattern = r"\b\d{1,3}(?: \d{3})* kr\b"

# find all addresses in the html files
adress_h2s = [soup.find_all("h2", class_="sold-property-listing__heading qa-selling-price-title hcl-card__title") for soup in soups]
adress_strs = [h2.text for resultSet in adress_h2s for h2 in resultSet]

# find all bo and bi areas in the html files
bo_and_bi_area_divs = [soup.find_all("div", class_="hcl-flex--container hcl-flex--gap-2 hcl-flex--justify-space-between hcl-flex--md-justify-flex-start") for soup in soups]
bo_and_bi_area_strs = [div.text for resultSet2 in bo_and_bi_area_divs for div in resultSet2]

dates = flatten([re.findall(date_of_sale_pattern, soup.text) for soup in soups])
dates = [f"{date[0]} {date[1]} {date[2]}" for date in dates]
adresses = flatten([re.findall(adress_pattern, str) for str in adress_strs])
locations = [item.strip().replace('\n', '') for item in flatten([re.findall(location_pattern, soups.text) for soups in soups]) if str(item).strip()]

bo_and_bi_areas = flatten([re.findall(bo_and_bi_area_pattern, soups.text) for soups in soups])
#nr_of_rooms = [re.findall(nr_of_rooms_pattern, soups.text) for soups in soups]
#area_of_plots = [re.findall(area_of_plot_pattern, soups.text) for soups in soups]
#closing_prices = [re.findall(closing_price_pattern, soups.text) for soups in soups]

print(dates)
print(adresses)
print(locations)
print(bo_and_bi_areas)
#print(nr_of_rooms)
#print(area_of_plots)
#print(closing_prices)
# Out:
# ['9 oktober 2023', '5 oktober 2023', '3 oktober 2023', '2 oktober 2023', '27 september 2023', '26 september 2023', '25 september 2023', '22 september 2023', '17 september 2023', '17 september 2023', '15 september 2023', '15 september 2023', '13 september 2023', '7 september 2023', '6 september 2023', '5 september 2023', '31 augusti 2023', '31 augusti 2023', '30 augusti 2023', '29 augusti 2023', '24 augusti 2023', '23 augusti 2023', '23 augusti 2023', '16 augusti 2023', '16 
 2022', '22 juni 2022', '22 juni 2022', '21 juni 2022', '21 juni 2022', '21 juni 2022', '20 juni 2022', '19 juni 2022', '17 juni 2022', '17 juni 2022', '16 juni 2022', '15 juni 2022', '15 juni 2022', '13 juni 2022', '11 juni 2022', '9 juni 2022', '9 juni 2022', '8 juni 2022', '6 juni 2022', '4 juni 2022', '3 juni 2022', '31 maj 2022', '31 maj 2022', '29 maj 2022', '27 maj 2022', '26 maj 2022', '26 maj 2022', '23 maj 2022', '22 maj 2022', '20 maj 2022', '17 maj 2022', '16 maj 2 ...
# ['Skårby station 350', 'Högalidsgatan 3', 'Kungälvsvägen 22', 'Ädelstensvägen 58', 'Kantorvägen 4', 'Diamantvägen 34', 'Tjäderstigen 8', 'Heavägen 31', 'Beryllvägen 14', 'Kornhall 290', 'Grindbacken 18', 'Korpvägen 273', 'Kristiansborg 300', 'Glöskär 255', 'Nolby 150', 'Skårby station 452', 'Snäckvägen 11', 'Klockarvägen 1', 'Lilla Fjellsholmen 35', 'Västra Röd 165', 'Jägarvägen 13', 'Rosenstensvägen 2', 'Tröskvägen 260', 'Stora Lycke 400', 'Dösebacka 410', 'Mantalsgatan 9', 'Skälebräckeliden 9', 'Norrmannebo 700', 'Bokvägen 14', 'Duvesjön 228', 'Klintegatan 22', 'Galärgatan 2', 'Ulvebackegatan 3', 'Vråstigen 4', 'Bergsvägen 11', 'Lundby 509', 'Kastellegårdsgatan 29', 'Sparråsvägen 140', 'Dammen 160', 'Önneröd 220', 'Tulpanvägen 15', 'Rubinvägen 19', 'Gårdskiftegatan 5', 'Norrmannebo 270', 'Dösebacka 120', 'Kärnavägen 16', 'Torp 250', 'Korpvägen 279', 'Västra gatan 48', 'Gunneröd 506', 'Oxelvägen 96', 'Solberg 420', 'Kovikshamn 160', 'Blankas gata 3', 'Ljungvägen 20', 'Rubinvägen 27', 'Ulvesund 419', 'Erslycke 140', 'Önneröd 145', 'Ställets bygata 156', 'Hallebäcksvägen 24', 'Bergkristallvägen 8', 'Hammarhöjden 670', 'Sålådevägen 554', 'Hjälmgatan 7', 'Strömgatan 9', 'Krappvägen 570', 'Norrmannebo 650', 'Ängsgatan  23', 'Stenåldersgatan 14', 'Spaghamnsvägen 7', 'Östergårdsgatan 3', 'Romelanda nedergård 160', 'Toreby 240', 'Murhammarvägen 12', 'Kämpegatan 4', 'Vesslegatan 14', 'Bastubäcksvägen 26', 'Karantänsgatan 9', 'Vävra 297', 'Lerskärsvägen 8', 'Brunnefjällsvägen 21', 'Klockarvägen 7', 'Sålådevägen 546', 'Östra Trädal 320', 'Lundby 565', 'Kuskalundsvägen 39', 'Häradsvägen 6', 'Kareby kyrkväg 149', 'Kuskalundsvägen 32', 'Munkegärdegatan 243', 'Backsippegatan 5', 'Stora Risby 550', 'Västra gatan 28', 'Östergårdsgatan 23', 'Hermansby 165', 'Lefstad 155', 'Kullegatan 12', 'Bräcke 105', 'Kulperödsvägen 17', 'Sköldgatan 8', 'Munkegärdegatan 279', 'Önneröd 120', 'Kyrkeby 293', 'Harkeröd 305', 'Lagvägen 23', 'Tegskiftegatan 84', 'Signehög 320', 'Guddehjälm 215', 'Kärnavägen 4', 'Källeröd 166', 'Korpedalsvägen 3', 'Hällristningsgatan 10', 'Kantorvägen 4', 'Gunneröd 320', 'Prästvägen 340', 'Granndalen 13', 'Stenåldersgatan 57', 'Duvesjön 216', 'Rostock 290', 'Långdammsvägen 2', 'Munkegärdegatan 312', 'Bremnäs 130', 'Bremnäs 155', 'Skurhagagatan 3', 'Restad 165', 'Sundhammarsvägen 610', 'Klevevägen 50', 'Klockarvägen 11', 'Hammarberg 830', 'Jordliden 30', 'Grindklykan 9', 'Hältorp 130', 'Häljeröd 430', 'Sjöhåla 130', 'Flädervägen 18', 'Lundby 440', 'Fiolmannens gata 17', 'Lefstad 350', 'Enskiftegatan 10', 'Mossvägen 38', 'Lingången 16', 'Jägersberg 310', 'Mossvägen 37', 'Prejelvägen 120', 'Vältvägen 509', 'Björröd 310', 'Kullholmsvägen 6', 'Kantorvägen 8', 'Norrmannebo 110', 'Heden 220', 'Gustavsbergsvägen 16', 'Bergsvägen 28', 'Korpvägen 263', 'Hemvägen 48', 'Häljeröd 640', 'Stenåldersgatan 55', 'Annas väg 28', 'Krokebäcksvägen 95', 'Björröd 260', 'Vävra 105', 'Högsberg 355', 'Rådjursgatan 8', 'Barlinds väg 38', 'Skålgropsgatan 28', 'Tjärnstigen 10', 'Grepvägen 385', 'Kyrkeby 302', 'Tvetgatan 143', 'Grandalen 230', 'Hammarhöjden 700', 'Holm 241', 'Torsby 270', 'Lerskärsvägen 52', 'Korsgatan 3', 'Blekeliden 6', 'Rörtången 273', 'Råckeröd 180', 'Krokebäcksvägen 85', 'Guddeby 210', 'Hallbjörtorp 330', 'Glöskär 875', 'Stora Risby 400', 'Hemmansgatan 7', 'Hemvägen 7', 'Ulvesund 296', 'Torsby 250', 'Åkerhög 340', 'Rondan 13', 'Blåsippegatan 12', 'Bergsvägen 4', 'Veneröd 439', 'Lefstadvägen 31', 'Silvergnejsvägen 18', 'Östra gatan 9', 'Apelvägen 10', 'Dösebacka 110', 'Lerskärsvägen 18', 'Halltorpsvägen 11', 'Duvesjön 351', 'Kärnavägen 50', 'Idrottsgatan 14', 'Äslingsvägen 10', 'Solberg 450', 'Almvägen 9', 'Flateby 525', 'Korpedalsvägen 9', 'Östergårdsgatan 23', 'Åsleröd 130', 'Rävo 131', 'Situlagatan 4', 'Duvesjön 373', 'Odlingsgatan 78', 'Östra gatan 29', 'Duvesjön 369', 'Tjuvkils huvud 918', 'Lagvägen 29', 'Lerskärsvägen 49', 'Sagagatan 6', 'Glose 120', 'Toreby 240', 'Tronnum 370', 'Ängsgatan 9', 'Storskiftegatan 35', 'Lerskärsvägen 36', ...
# ['Kareby,          Kungälvs kommun', 'Centrum,          Kungälvs kommun', 'Centralt,          Kungälvs kommun', 'Kode,          Kungälvs kommun', 'Bohuslän,          Kungälvs kommun', 'Kode,          Kungälvs kommun', 'Centralt,          Kungälvs kommun', 'Lycke,          Kungälvs kommun', 'Kode,          Kungälvs kommun', 'Kornhall,          Kungälvs kommun', 'Grinden,          Kungälvs kommun', 'Ullstorp,          Kungälvs kommun', 'Bohuslän,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Kode,          Kungälvs kommun', 'Kareby,          Kungälvs kommun', 'Kode,          Kungälvs kommun', 'Bohuslän,          Kungälvs kommun', 'Vedhall,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Komarken,          Kungälvs kommun', 'Romelanda,          Kungälvs kommun', 'Kungälv,          Kungälvs kommun', 'Ullstorp,          Kungälvs kommun', 'Bohuslän,          Kungälvs kommun', 'Romelanda,          Kungälvs kommun', 'Tega,          Kungälvs kommun', 'Centrum,          Kungälvs kommun', 'Romelanda,          Kungälvs kommun', 'centrum,          Kungälvs kommun', 'Romelanda,          Kungälvs kommun', 'Centralt,          Kungälvs kommun', 'Centrum,          Kungälvs kommun', 'Munkegärde,          Kungälvs kommun', 'Överön,          Kungälvs kommun', 'Ödsmålsmosse,          Kungälvs kommun', 'Kareby,          Kungälvs kommun', 'Komarken,          Kungälvs kommun', 'Ytterby,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Kode,          Kungälvs kommun', 'Ytterby,          Kungälvs kommun', 'Romelanda, Kungälvs kommun', 'Romelanda,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Kareby,          Kungälvs kommun', 'Ullstorp,          Kungälvs kommun', 'Centralt,          Kungälvs kommun', 'Villor, Kungälvs kommun', 'Villor, Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Diseröd,          Kungälvs kommun', 'Romelanda,          Kungälvs kommun', 'Kovikshamn,          Kungälvs kommun', 'Centralt,          Kungälvs kommun', 'Kode,          Kungälvs kommun', 'Kode,          Kungälvs kommun', 'Ulvesund,          Kungälvs kommun', 'Lycke,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Ytterby,          Kungälvs kommun', 'Timmervik,          Kungälvs kommun', 'Kode,          Kungälvs kommun', 'Bohuslän,          Kungälvs kommun', 'Ullstorp,          Kungälvs kommun', 'Ytterby,          Kungälvs kommun', 'Ytterby,          Kungälvs kommun', 'Ullstorp,          Kungälvs kommun', 'Bohuslän,          Kungälvs kommun', 'Centralt,          Kungälvs kommun', 'Stället,          Kungälvs kommun', 'Tjuvkil,          Kungälvs kommun', 'Ytterby,          Kungälvs kommun', 'Romelanda,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Kareby,          Kungälvs kommun', 'Centrum,          Kungälvs kommun', 'Olseröd,          Kungälvs kommun', 'Kode,          Kungälvs kommun', 'Centrum,          Kungälvs kommun', 'Hålta,          Kungälvs kommun', 'Tjuvkil,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Romelanda,          Kungälvs kommun', 'Ullstorp,          Kungälvs kommun', 'Ytterby,          Kungälvs kommun', 'Kareby,          Kungälvs kommun', 'Hålta,          Kungälvs kommun', 'Ytterby,          Kungälvs kommun', 'Kareby,          Kungälvs kommun', 'Hålta,          Kungälvs kommun', 'Ulvegärde,          Kungälvs kommun', 'Ytterby,          Kungälvs kommun', 'Hålta,          Kungälvs kommun', 'Centralt,          Kungälvs kommun', 'Ytterby,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Centrum,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Villor, Kungälvs kommun', 'Villor, Kungälvs kommun', 'Bohuslän,          Kungälvs kommun', 'Stället,          Kungälvs kommun', 'Munkegärde,          Kungälvs kommun', 'Kärna,          Kungälvs kommun', 'Harestad,          Kungälvs kommun', 'Hålta,          Kungälvs kommun',  ...
# []
